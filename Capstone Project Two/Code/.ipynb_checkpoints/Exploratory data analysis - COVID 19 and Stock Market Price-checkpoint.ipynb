# %%
import pandas as pd
import numpy as np
import datetime as dt
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
file = r'C:\\Users\\mshus\\Google Drive\\Data Science - Springboard\\Git_GitHub\\Springboard\\Capstone Project Two\\Data\US_stock_covid_df.csv'

# %%
data = pd.read_csv(file, index_col = 0)

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)

# %%
data.head()
# Out:
#             confirmed  death  recovered       High    Low       Open  \
# Date
# 2020-01-22          1      0          0  58.970001  58.02  58.950001
# 2020-01-23          1      0          0  57.980000  57.02  57.599998
# 2020-01-24          2      0          0  57.799999  56.84  57.730000
# 2020-01-27          5      0          0  55.689999  54.82  55.139999
# 2020-01-28          5      0          0  56.090000  55.16  55.490002
#
#                 Close    Volume  Adj Close
# Date
# 2020-01-22  58.180000  169600.0  54.887253
# 2020-01-23  57.770000  227900.0  54.500458
# 2020-01-24  57.160000  146200.0  53.924980
# 2020-01-27  55.279999  230600.0  52.151379
# 2020-01-28  55.500000  174400.0  52.358929

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 130 entries, 2020-01-22 to 2020-07-27
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   confirmed  130 non-null    int64
#  1   death      130 non-null    int64
#  2   recovered  130 non-null    int64
#  3   High       130 non-null    float64
#  4   Low        130 non-null    float64
#  5   Open       130 non-null    float64
#  6   Close      130 non-null    float64
#  7   Volume     130 non-null    float64
#  8   Adj Close  130 non-null    float64
# dtypes: float64(6), int64(3)
# memory usage: 10.2+ KB

# %% [markdown]
# # Data Profile, Table and Plots

# %%
data.describe()
# Out:
#           confirmed          death     recovered        High         Low  \
# count  1.300000e+02     130.000000  1.300000e+02  130.000000  130.000000
# mean   1.179489e+06   58064.976923  2.956471e+05   48.707462   47.671846
# std    1.232264e+06   55033.155993  3.768308e+05    4.007779    4.032894
# min    1.000000e+00       0.000000  0.000000e+00   42.020000   41.299999
# 25%    5.670000e+02      23.500000  7.250000e+00   45.315001   44.190000
# 50%    8.897625e+05   51808.000000  8.964100e+04   48.080000   46.875000
# 75%    1.995508e+06  113401.750000  5.313418e+05   52.147499   50.697499
# max    4.290259e+06  148011.000000  1.325804e+06   58.970001   58.020000
#
#              Open       Close        Volume   Adj Close
# count  130.000000  130.000000  1.300000e+02  130.000000
# mean    48.242154   48.200308  2.499415e+05   46.243837
# std      4.085831    4.000952  1.436442e+05    3.153128
# min     41.880001   41.830002  8.100000e+04   39.755051
# 25%     44.682500   44.929999  1.593500e+05   44.087502
# 50%     47.425001   47.484999  2.227500e+05   45.489910
# 75%     51.725000   51.537500  2.940000e+05   48.620691
# max     58.950001   58.180000  1.103800e+06   54.887253

# %%
data.tail()
# Out:
#             confirmed   death  recovered       High        Low       Open  \
# Date
# 2020-07-21    3899211  142121    1182018  43.619999  42.889999  42.889999
# 2020-07-22    3970121  143316    1210849  45.070000  43.959999  44.099998
# 2020-07-23    4038816  144430    1233269  45.689999  44.090000  44.529999
# 2020-07-24    4112531  145560    1261624  44.869999  44.290001  44.700001
# 2020-07-27    4290259  148011    1325804  45.099998  44.669998  44.680000
#
#                 Close    Volume  Adj Close
# Date
# 2020-07-21  43.090000  226700.0  43.090000
# 2020-07-22  45.049999  234600.0  45.049999
# 2020-07-23  45.470001  440800.0  45.470001
# 2020-07-24  44.619999  143200.0  44.619999
# 2020-07-27  45.060001   88200.0  45.060001

# %%
data.boxplot(figsize = (12,10), fontsize = 14, vert = False)

# %%
data.hist(figsize = (20, 20), bins = 20)
plt.show()

# %% [markdown]
# #  Data Relationship

# %%
data.corr()
# Out:
#            confirmed     death  recovered      High       Low      Open  \
# confirmed   1.000000  0.964143   0.981590 -0.740519 -0.689675 -0.714507
# death       0.964143  1.000000   0.911418 -0.763980 -0.710532 -0.732173
# recovered   0.981590  0.911418   1.000000 -0.710429 -0.661069 -0.688613
# High       -0.740519 -0.763980  -0.710429  1.000000  0.991391  0.993059
# Low        -0.689675 -0.710532  -0.661069  0.991391  1.000000  0.993917
# Open       -0.714507 -0.732173  -0.688613  0.993059  0.993917  1.000000
# Close      -0.713932 -0.739476  -0.681567  0.995023  0.993702  0.990834
# Volume     -0.354420 -0.373503  -0.316429 -0.017674 -0.107257 -0.067127
# Adj Close  -0.543224 -0.581415  -0.491874  0.942602  0.958777  0.946093
#
#               Close    Volume  Adj Close
# confirmed -0.713932 -0.354420  -0.543224
# death     -0.739476 -0.373503  -0.581415
# recovered -0.681567 -0.316429  -0.491874
# High       0.995023 -0.017674   0.942602
# Low        0.993702 -0.107257   0.958777
# Open       0.990834 -0.067127   0.946093
# Close      1.000000 -0.043653   0.959448
# Volume    -0.043653  1.000000  -0.154066
# Adj Close  0.959448 -0.154066   1.000000

# %%
plt.figure(figsize=(14,12))
sns.heatmap(data.corr(), linewidths = .5, annot = True, cmap = 'YlGnBu')

# %%
# Define function to calculate and display the list of correlated variables
def list_of_correlated_var(df):
    corr_matrix = df.drop('Adj Close', axis =1).corr().abs() #  Exclude Adjusted closing price - used as target variable
    high_corr_var=np.where(corr_matrix>0.8) # value more than 0.8 is considered to be correlated
    high_corr_var=[(corr_matrix.index[x],corr_matrix.columns[y]) for x,y in zip(*high_corr_var) if x!=y and x<y]

    #convert list of hihgly correlated to DataFrame
    list_of_hihgly_correlated_var = (pd.DataFrame(list(high_corr_var)))
    list_of_hihgly_correlated_var.columns = ['factor_one', 'factor_two']

    # For better readability, start index from one
    list_of_hihgly_correlated_var.index += 1
    return list_of_hihgly_correlated_var

# %%
# call function on all variables -
list_of_correlated_var(data)
# Out:
#   factor_one factor_two
# 1  confirmed      death
# 2  confirmed  recovered
# 3      death  recovered
# 4       High        Low
# 5       High       Open
# 6       High      Close
# 7        Low       Open
# 8        Low      Close
# 9       Open      Close

# %%
sns.pairplot(data)

# %% [markdown]
# ## Drop the Highly Correlated Variables

# %%
#Copy the dataset
df_clean = data

# %%
df_clean.columns
# Out:
# Index(['confirmed', 'death', 'recovered', 'High', 'Low', 'Open', 'Close',
#        'Volume', 'Adj Close'],
#       dtype='object')

# %%
df_clean =df_clean.rename(columns = {'Adj Close': 'adjusted_close'})
df_clean.head()
# Out:
#             confirmed  death  recovered       High    Low       Open  \
# Date
# 2020-01-22          1      0          0  58.970001  58.02  58.950001
# 2020-01-23          1      0          0  57.980000  57.02  57.599998
# 2020-01-24          2      0          0  57.799999  56.84  57.730000
# 2020-01-27          5      0          0  55.689999  54.82  55.139999
# 2020-01-28          5      0          0  56.090000  55.16  55.490002
#
#                 Close    Volume  adjusted_close
# Date
# 2020-01-22  58.180000  169600.0       54.887253
# 2020-01-23  57.770000  227900.0       54.500458
# 2020-01-24  57.160000  146200.0       53.924980
# 2020-01-27  55.279999  230600.0       52.151379
# 2020-01-28  55.500000  174400.0       52.358929

# %%
df_clean.to_csv(r'C:\\Users\\mshus\\Google Drive\\Data Science - Springboard\\Git_GitHub\\Springboard\\Capstone Project Two\\Data\df_clean.csv')
